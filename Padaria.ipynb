# %% [markdown]
# # Padaria

# %% [markdown]
# A padaria está enfrentando um alto índice de desperdício de alimentos e gostaria de encontrar maneiras de aumentar as vendas e reduzir o desperdício. Vamos analisar os dados disponíveis sobre os produtos vendidos na padaria e identificar oportunidades para otimizar o estoque e melhorar a gestão dos produtos.

# %%
# Passo 1: Importar bibliotecas
# começaremos importando as bibliotecas necessárias para realizar a análise de dados. 
# Utilizaremos as bibliotecas Pandas para manipulação de dados e Matplotlib para visualização dos resultados.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Ler o arquivo CSV
df = pd.read_csv('dados_padaria.csv')

# %%
# Verificar Colunas do Dataframe
df.columns
# Out:
# Index(['Data', 'Produto', 'Categoria', 'Quantidade Vendida',
#        'Quantidade Desperdiçada'],
#       dtype='object')

# %% [markdown]
# Agora temos um DataFrame chamado "df" com informações sobre as vendas da padaria.
#
# Passo 3: Análise exploratória dos dados
# Agora faremos uma análise exploratória dos dados para entender melhor o conjunto de dados e identificar possíveis oportunidades de melhoria.

# %%
# 3.1. Verificar as primeiras linhas do DataFrame:
print(df.head())
# Out:
#          Data                Produto                      Categoria  \
# 0  2023-09-13  Bolacha (ou biscoito)  Produtos que não podem faltar
# 1  2021-06-14                Cocadas                          Doces
# 2  2019-11-20                Iogurte                     Laticínios
# 3  2021-05-26               Salgados  Produtos que não podem faltar
# 4  2020-09-20               Sorvetes                        Gelados
#
#    Quantidade Vendida  Quantidade Desperdiçada
# 0                   5                        3
# 1                   8                        3
# 2                   2                        2
# 3                   6                        2
# 4                   3                        3

# %%
# 3.2. Verificar informações básicas do DataFrame:
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Data                     1000 non-null   object
#  1   Produto                  1000 non-null   object
#  2   Categoria                1000 non-null   object
#  3   Quantidade Vendida       1000 non-null   int64
#  4   Quantidade Desperdiçada  1000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 39.2+ KB
# None

# %%
# 3.3. Verificar estatísticas descritivas do DataFrame:
print(df.describe())
# Out:
#        Quantidade Vendida  Quantidade Desperdiçada
# count         1000.000000              1000.000000
# mean             5.542000                 1.481000
# std              2.801086                 1.130893
# min              1.000000                 0.000000
# 25%              3.000000                 0.000000
# 50%              6.000000                 1.000000
# 75%              8.000000                 3.000000
# max             10.000000                 3.000000

# %%
# 3.4. Visualizar a distribuição da quantidade vendida por categoria:

plt.figure(figsize=(12, 6))
plt.xticks(rotation=45)
plt.title('Distribuição da quantidade vendida por categoria')
sns.boxplot(x='Categoria', y='Quantidade Vendida', data=df)
plt.show()

# %%
# Passo 4: Pré-processamento dos dados
# Nesta etapa, faremos o pré-processamento dos dados, o que inclui lidar com valores ausentes, 
# realizar transformações necessárias e preparar os dados para a análise posterior.

# 4.1. Verificar e tratar valores ausentes:

print(df.isnull().sum())

# Caso haja valores ausentes, podemos preenchê-los com zero
df.fillna(0, inplace=True)
# Out:
# Data                       0
# Produto                    0
# Categoria                  0
# Quantidade Vendida         0
# Quantidade Desperdiçada    0
# dtype: int64

# %%
# .2. Transformar variáveis categóricas em numéricas:

# Utilizaremos a técnica de one-hot encoding para transformar a coluna "Categoria" em variáveis dummy
df_encoded = pd.get_dummies(df, columns=['Categoria'])

# %% [markdown]
# Passo 5: Análise de dados e criação do dashboard
# Nesta etapa, utilizaremos os dados pré-processados para realizar uma análise mais aprofundada e criar um dashboard complexo
# que fornecerá informações visuais sobre as vendas e o desperdício de produtos da padaria.
#
# Para criar o dashboard, podemos utilizar bibliotecas como Plotly e Dash, que permitem a criação de painéis interativos.

# %% [markdown]
# Ao executar o código aabaixo, você verá o dashboard interativo em seu navegador, exibindo informações sobre as vendas da padaria.
#
# Essas são as etapas gerais para realizar uma análise de dados, pré-processamento e criação de um dashboard para um problema de uma padaria. Obviamente, você pode adaptar e personalizar o código de acordo com suas necessidades específicas.

# %% [markdown]
# Para aplicar a técnica de storytelling ao dashboard em Python, podemos utilizar a biblioteca Plotly e o Dash para criar visualizações interativas e narrativas que contem uma história sobre as vendas e o desperdício de produtos da padaria. Vou apresentar um exemplo de como isso pode ser feito:

# %% [markdown]
# EXECUTAR O CODIGO ABAIXO SÓ SE QUISER VER ELE DENTRO DO VSCODE, CASO QUEIRA VERIFICAR NO NAVEGADOR
# DEVE EXETUTAR OS SEGUINTES COMANDO NO TERMINAL DO VSCODE
#
# pip install pandas plotly dash
#
#
# Para visualizar o dashboard no navegador, você precisa executar o código Python que cria o dashboard usando o Dash. Siga estas etapas:
#
# Certifique-se de ter todas as dependências instaladas. Você pode usar o pip para instalar as bibliotecas necessárias. Por exemplo:
# Copy code
#
# pip install pandas plotly dash
#
# Salve o código do dashboard em um arquivo Python, por exemplo, dashboard.py.
#
# Abra o prompt de comando ou o terminal e navegue até o diretório onde você salvou o arquivo dashboard.py.
#
# Execute o seguinte comando para iniciar o servidor Dash:
#
# python dashboard.py
#
# Após executar o comando acima, você verá uma mensagem indicando que o servidor está sendo executado e qual URL acessar. Por exemplo:
#
# Dash is running on http://127.0.0.1:8050/

# %% [markdown]
# Neste exemplo, o dashboard inclui uma dropdown para selecionar o mês e o ano, bem como três elementos: duas visualizações (gráficos) e um texto narrativo. Ao selecionar um mês e um ano no dropdown, as visualizações e o texto serão atualizados com os dados correspondentes. Isso permite que o usuário navegue na história e explore diferentes períodos de vendas e desperdício.
#
# Lembrando que é necessário ter um arquivo CSV chamado "dados_padaria.csv" contendo os dados da padaria, com as colunas "Data", "Produto", "Categoria", "Quantidade Vendida" e "Quantidade Desperdiçada".

# %% [markdown]
# Com base na análise de dados realizada e nos insights obtidos, podemos extrair algumas informações relevantes que podem subsidiar a tomada de decisão para melhorar as vendas e reduzir o desperdício na padaria. Aqui estão alguns insights que podem ser considerados:
#
# Identificar os produtos mais vendidos: Analisar os dados de quantidade vendida por produto e categoria pode ajudar a identificar quais produtos têm maior demanda. Com base nisso, a padaria pode priorizar o estoque e o abastecimento desses itens para garantir que não faltem nas prateleiras.
#
# Analisar a sazonalidade das vendas: Verificar os padrões de vendas ao longo do tempo, considerando meses e anos, pode revelar sazonalidades. Por exemplo, se houver um aumento nas vendas de sorvetes e picolés durante os meses mais quentes, a padaria pode adaptar seu estoque e promoções para atender a essa demanda sazonal.
#
# Avaliar o desperdício de produtos: Analisar os dados de desperdício de produtos pode revelar quais itens estão sendo mais desperdiçados. Identificar as causas do desperdício, como prazo de validade vencido, demanda insuficiente ou problemas de armazenamento, permitirá tomar medidas para reduzir o desperdício, como ajustar as quantidades produzidas ou melhorar as práticas de armazenamento.
#
# Explorar oportunidades de cross-selling: Analisar a correlação entre as categorias de produtos vendidos pode revelar oportunidades de cross-selling. Por exemplo, se for observada uma forte correlação entre a venda de pães e laticínios, a padaria pode criar promoções combinando esses produtos para incentivar os clientes a comprarem ambos.
#
# Monitorar a rentabilidade por categoria: Além de analisar as vendas, é importante considerar a rentabilidade dos produtos. A padaria pode calcular a margem de lucro por categoria e identificar quais categorias são mais rentáveis. Isso pode ajudar na tomada de decisão sobre o mix de produtos e as estratégias de precificação.
#
# Realizar análise de demanda futura: Com base nos dados históricos de vendas, é possível realizar previsões de demanda futura usando técnicas de análise de séries temporais. Isso pode ser útil para planejar o estoque, as compras de ingredientes e até mesmo para desenvolver promoções direcionadas.
#
# Esses insights podem servir como base para tomar decisões estratégicas para aumentar as vendas e reduzir o desperdício na padaria. É importante envolver os diferentes departamentos da padaria, como produção, estoque e marketing, para implementar as ações necessárias com base nessas informações. A análise de dados contínua e a monitoração dos resultados também são fundamentais para ajustar as estratégias e garantir a eficácia das decisões tomadas.
